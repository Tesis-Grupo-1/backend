# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import ResNet50 # type: ignore
from tensorflow.keras import layers, models # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.metrics import Precision, Recall, AUC, F1Score # type: ignore
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array # type: ignore
from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore
from tensorflow.keras import backend as K # type: ignore
from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore
from tensorflow.keras.optimizers.schedules import ExponentialDecay # type: ignore
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore
from tensorflow.keras.models import load_model  # type: ignore

# %%
class ImageDataset:
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.images = []
        self.labels = []

    def load_data(self):
        for label in ['plaga', 'sana']:
            label_dir = os.path.join(self.data_dir, label)
            for image_name in os.listdir(label_dir):
                img_path = os.path.join(label_dir, image_name)
                img_array = self.load_and_preprocess_image(img_path)
                if img_array is not None:
                    self.images.append(img_array)
                    self.labels.append(self.assign_label(label))

    def load_and_preprocess_image(self, img_path):
        try:
            img = load_img(img_path, target_size=(224, 224))  # Redimensionar
            img_array = img_to_array(img) / 255.0  # Normalizar
            return img_array
        except OSError as e:
            print(f"Error al cargar la imagen {img_path}: {e}")
            return None

    def assign_label(self, label):
        return 1 if label == 'plaga' else 0  # Etiquetas binarias

# %%
class ResNetModel:
    def __init__(self):
        """Usamos ResNet50 como base y agregamos capas de salida."""
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


        base_model.trainable = False #Congelar las capas de la base para evitar el sobreajuste
        
        
        self.model = models.Sequential([
            base_model,
            layers.GlobalAveragePooling2D(),  # Promedio global de las características
            layers.Dropout(0.2),
            layers.Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
            layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
            layers.Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
            layers.Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
            layers.Dense(1, activation='sigmoid')  # Salida binaria (plaga o sana)
        ])
        
    

    def compile(self):
        """Compila el modelo."""
        
        lr_schedule = ExponentialDecay(
            initial_learning_rate=0.001, #Valor inicial del learning rate
            decay_steps=50000,  # Número de pasos antes de reducir el learning rate
            decay_rate=0.96,     # Factor de reducción en cada paso
            staircase=True       # Si se debe hacer el descenso en "escalones"
        )
        
        optimizer = Adam(learning_rate=lr_schedule) # Usamos Adam con un scheduler de decaimiento exponencial
        
        self.model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', AUC(), F1Score()]) 

    def train(self, X_train, y_train, X_val, y_val, epochs=6, batch_size=32):
        """Entrena el modelo con data augmentation.""" 


        # Early stopping
        early_stopping = EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True

        )
        
        # Entrenar el modelo usando el generador de aumento de datos
        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,  # Usamos el generador para la entrada
            epochs=epochs,
            validation_data=(X_val, y_val),
            callbacks=[early_stopping],
            verbose=1
        )
        
        return history


    def evaluate(self, X_val, y_val):
        """Evalúa el modelo con los datos de validación."""
        loss, accuracy, auc, f1 = self.model.evaluate(X_val, y_val)
        print(f'Pérdida: {loss}, Accuracy: {accuracy}, AUC: {auc}, F1-Score: {f1}')
        return loss, accuracy, auc, f1

    def save(self, model_name='modelo_entrenado_resnet.h5'):
        """Guarda el modelo entrenado."""
        self.model.save(model_name)

# %%
data_dir = 'data/'  # Cambia a la ruta de tus imágenes
dataset = ImageDataset(data_dir)
dataset.load_data()

# Convertir listas a arrays de NumPy
images = np.array(dataset.images)
labels = np.array(dataset.labels)


# Dividir las imágenes en entrenamiento (80%) y validación (20%)
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

# Agregar una dimensión adicional para la metrica de f1-score 
y_train  = np.expand_dims(y_train, axis=-1)
y_val = np.expand_dims(y_val, axis=-1) 

# Crear y entrenar el modelo
model = ResNetModel()
model.compile()
history = model.train(X_train, y_train, X_val, y_val, epochs=100)

# Evaluar el modelo
loss, accuracy, auc, f1 = model.evaluate(X_val, y_val)
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 351s 4s/step - accuracy: 0.6963 - auc_1: 0.7761 - f1_score: 0.6767 - loss: 1.4436 - val_accuracy: 0.8493 - val_auc_1: 0.9303 - val_f1_score: 0.6942 - val_loss: 0.7597
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 313s 4s/step - accuracy: 0.8492 - auc_1: 0.9067 - f1_score: 0.6647 - loss: 0.7037 - val_accuracy: 0.8363 - val_auc_1: 0.9352 - val_f1_score: 0.6942 - val_loss: 0.6848
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 313s 4s/step - accuracy: 0.8438 - auc_1: 0.9069 - f1_score: 0.6652 - loss: 0.6157 - val_accuracy: 0.8314 - val_auc_1: 0.9392 - val_f1_score: 0.6942 - val_loss: 0.6387
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 260s 3s/step - accuracy: 0.8496 - auc_1: 0.9103 - f1_score: 0.6671 - loss: 0.5620 - val_accuracy: 0.5413 - val_auc_1: 0.9387 - val_f1_score: 0.6942 - val_loss: 1.1061
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.7964 - auc_1: 0.8743 - f1_score: 0.6490 - loss: 0.6458 - val_accuracy: 0.8266 - val_auc_1: 0.9448 - val_f1_score: 0.6942 - val_loss: 0.5429
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 310s 4s/step - accuracy: 0.8158 - auc_1: 0.8945 - f1_score: 0.6541 - loss: 0.5632 - val_accuracy: 0.8379 - val_auc_1: 0.9452 - val_f1_score: 0.6942 - val_loss: 0.5170
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 303s 4s/step - accuracy: 0.8596 - auc_1: 0.9158 - f1_score: 0.6707 - loss: 0.4863 - val_accuracy: 0.8736 - val_auc_1: 0.9443 - val_f1_score: 0.6942 - val_loss: 0.4467
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 173s 2s/step - accuracy: 0.8735 - auc_1: 0.9299 - f1_score: 0.6624 - loss: 0.4492 - val_accuracy: 0.8298 - val_auc_1: 0.9495 - val_f1_score: 0.6942 - val_loss: 0.5037
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8621 - auc_1: 0.9303 - f1_score: 0.6595 - loss: 0.4399 - val_accuracy: 0.8882 - val_auc_1: 0.9501 - val_f1_score: 0.6942 - val_loss: 0.4055
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.8682 - auc_1: 0.9312 - f1_score: 0.6659 - loss: 0.4227 - val_accuracy: 0.8833 - val_auc_1: 0.9493 - val_f1_score: 0.6942 - val_loss: 0.3992
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.8756 - auc_1: 0.9318 - f1_score: 0.6754 - loss: 0.4064 - val_accuracy: 0.8136 - val_auc_1: 0.9520 - val_f1_score: 0.6942 - val_loss: 0.5095
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.8270 - auc_1: 0.8904 - f1_score: 0.6621 - loss: 0.5101 - val_accuracy: 0.8882 - val_auc_1: 0.9476 - val_f1_score: 0.6942 - val_loss: 0.3928
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.8326 - auc_1: 0.9182 - f1_score: 0.6698 - loss: 0.4504 - val_accuracy: 0.8914 - val_auc_1: 0.9466 - val_f1_score: 0.6942 - val_loss: 0.3933
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8706 - auc_1: 0.9302 - f1_score: 0.6568 - loss: 0.3980 - val_accuracy: 0.8460 - val_auc_1: 0.9495 - val_f1_score: 0.6942 - val_loss: 0.4310
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8547 - auc_1: 0.9172 - f1_score: 0.6539 - loss: 0.4345 - val_accuracy: 0.8817 - val_auc_1: 0.9489 - val_f1_score: 0.6942 - val_loss: 0.3751
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8652 - auc_1: 0.9312 - f1_score: 0.6568 - loss: 0.3938 - val_accuracy: 0.8914 - val_auc_1: 0.9492 - val_f1_score: 0.6942 - val_loss: 0.3534
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8631 - auc_1: 0.9302 - f1_score: 0.6628 - loss: 0.3855 - val_accuracy: 0.8801 - val_auc_1: 0.9512 - val_f1_score: 0.6942 - val_loss: 0.3503
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8819 - auc_1: 0.9306 - f1_score: 0.6564 - loss: 0.3750 - val_accuracy: 0.8930 - val_auc_1: 0.9509 - val_f1_score: 0.6942 - val_loss: 0.3452
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.8772 - auc_1: 0.9330 - f1_score: 0.6667 - loss: 0.3736 - val_accuracy: 0.8914 - val_auc_1: 0.9499 - val_f1_score: 0.6942 - val_loss: 0.3756
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8829 - auc_1: 0.9351 - f1_score: 0.6653 - loss: 0.3738 - val_accuracy: 0.8865 - val_auc_1: 0.9514 - val_f1_score: 0.6942 - val_loss: 0.3401
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.8850 - auc_1: 0.9388 - f1_score: 0.6752 - loss: 0.3537 - val_accuracy: 0.8428 - val_auc_1: 0.9548 - val_f1_score: 0.6942 - val_loss: 0.4224
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.8396 - auc_1: 0.9162 - f1_score: 0.6621 - loss: 0.4184 - val_accuracy: 0.8865 - val_auc_1: 0.9504 - val_f1_score: 0.6942 - val_loss: 0.3517
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.8776 - auc_1: 0.9361 - f1_score: 0.6641 - loss: 0.3600 - val_accuracy: 0.8801 - val_auc_1: 0.9521 - val_f1_score: 0.6942 - val_loss: 0.3410
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.8802 - auc_1: 0.9404 - f1_score: 0.6584 - loss: 0.3544 - val_accuracy: 0.8849 - val_auc_1: 0.9542 - val_f1_score: 0.6942 - val_loss: 0.3308
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.8570 - auc_1: 0.9273 - f1_score: 0.6617 - loss: 0.3840 - val_accuracy: 0.8817 - val_auc_1: 0.9529 - val_f1_score: 0.6942 - val_loss: 0.3573
# Epoch 26/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.8720 - auc_1: 0.9276 - f1_score: 0.6689 - loss: 0.3738 - val_accuracy: 0.8914 - val_auc_1: 0.9578 - val_f1_score: 0.6942 - val_loss: 0.3361
# Epoch 27/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.8663 - auc_1: 0.9285 - f1_score: 0.6583 - loss: 0.3745 - val_accuracy: 0.8720 - val_auc_1: 0.9544 - val_f1_score: 0.6942 - val_loss: 0.3847
# Epoch 28/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.8708 - auc_1: 0.9393 - f1_score: 0.6745 - loss: 0.3566 - val_accuracy: 0.8898 - val_auc_1: 0.9548 - val_f1_score: 0.6942 - val_loss: 0.3328
# Epoch 29/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8831 - auc_1: 0.9338 - f1_score: 0.6575 - loss: 0.3572 - val_accuracy: 0.8882 - val_auc_1: 0.9561 - val_f1_score: 0.6942 - val_loss: 0.3474
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.8759 - auc_1: 0.9489 - f1_score: 0.6896 - loss: 0.3567
# Pérdida: 0.3308122158050537, Accuracy: 0.8849270939826965, AUC: 0.954236626625061, F1-Score: 0.6941798329353333

# %%
# Obtener predicciones como probabilidades
y_pred_probs = model.model.predict(X_val)

# Convertir probabilidades a etiquetas binarias
y_pred_classes = (y_pred_probs >= 0.5).astype(int)

y_val = np.expand_dims(y_val, axis=-1)  # → (617, 1)
y_val_flat = y_val.flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_val_flat, y_pred_classes)

# Visualización
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Sano', 'Plaga'], yticklabels=['Sano', 'Plaga'])
plt.xlabel('Predicción')
plt.ylabel('Real')
plt.title('Matriz de Confusión')
plt.show()

# Reporte detallado
print(classification_report(y_val_flat, y_pred_classes, target_names=['Sano', 'Plaga']))
# Out:
#               precision    recall  f1-score   support
#
#         Sano       0.87      0.89      0.88       289
#        Plaga       0.90      0.88      0.89       328
#
#     accuracy                           0.88       617
#    macro avg       0.88      0.88      0.88       617
# weighted avg       0.89      0.88      0.88       617

# %%
predictions = model.model.predict(X_val)  # Obtener las predicciones del modelo

# Seleccionar las primeras `num_images` imágenes para mostrar
random_indices = np.random.choice(len(X_val), size=10, replace=False)  # Elegir 5 índices aleatorios

# Mostrar las imágenes seleccionadas aleatoriamente
for i in random_indices:
        img = X_val[i]  # Imagen de validación
        label = 'Plaga' if y_val[i] == 1 else 'Sana'  # Etiqueta real
        pred = 'Plaga' if predictions[i] > 0.5 else 'Sana'  # Predicción del modelo
        
        # Mostrar la imagen
        plt.figure(figsize=(5, 5))
        plt.imshow(img)  # Mostrar la imagen
        plt.axis('off')  # Sin ejes
        plt.title(f"Real: {label} | Predicción: {pred}")
        plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step

# %%
import matplotlib.pyplot as plt

def plot_training_history(history, loss_name):
    # Graficar la evolución de las métricas durante el entrenamiento
    plt.figure(figsize=(16, 12))

    # Accuracy durante el entrenamiento
    plt.subplot(2, 2, 1)
    plt.plot(history.history['accuracy'], label='Accuracy de Entrenamiento')
    plt.plot(history.history['val_accuracy'], label='Accuracy de Validación')
    plt.title(f'Accuracy durante el Entrenamiento ({loss_name})')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión')
    plt.legend()

    # Pérdida durante el entrenamiento
    plt.subplot(2, 2, 2)
    plt.plot(history.history['loss'], label='Pérdida de Entrenamiento')
    plt.plot(history.history['val_loss'], label='Pérdida de Validación')
    plt.title(f'Pérdida durante el Entrenamiento ({loss_name})')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    # AUC durante el entrenamiento
    plt.subplot(2, 2, 3)
    plt.plot(history.history['auc'], label='AUC de Entrenamiento')
    plt.plot(history.history['val_auc'], label='AUC de Validación')
    plt.title(f'AUC durante el Entrenamiento ({loss_name})')
    plt.xlabel('Épocas')
    plt.ylabel('AUC')
    plt.legend()

    # F1-Score durante el entrenamiento
    plt.subplot(2, 2, 4)
    plt.plot(history.history['f1_score'], label='F1-Score de Entrenamiento')
    plt.plot(history.history['val_f1_score'], label='F1-Score de Validación')
    plt.title(f'F1-Score durante el Entrenamiento ({loss_name})')
    plt.xlabel('Épocas')
    plt.ylabel('F1-Score')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Graficar el historial de entrenamiento
plot_training_history(history, "Binary Cross-Entropy")
